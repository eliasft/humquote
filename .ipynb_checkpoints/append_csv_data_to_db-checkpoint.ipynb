# %%
import pandas as pd
import sqlite3

# Path to your CSV file
csv_file_path = 'all-futures-data.csv'
# Path to your SQLite database file
db_file_path = 'futures_prices.db'
# Name of the table to which the data will be appended
table_name = 'futures_data'

def create_connection(db_file):
    """Create and return a connection to the database."""
    try:
        conn = sqlite3.connect(db_file)
        print("Connection established")
        return conn
    except sqlite3.Error as e:
        print(f"Error connecting to database: {e}")
    return None

def pivot_dataframe(df):
    """Pivot the DataFrame to wide format."""
    df_pivot = df.pivot_table(index=['Quote Date', 'Year'], columns='State', values='Price', aggfunc='first').reset_index()
    return df_pivot

def append_csv_to_database(csv_file, db_file, table):
    # Read the CSV file into a DataFrame
    df = pd.read_csv(csv_file)
    
    # Convert 'Quote Date' to datetime and sort in descending order
    df['Quote Date'] = pd.to_datetime(df['Quote Date'])
    
    
    df_wide = pivot_dataframe(df)
    df_sorted = df_wide.sort_values(by='Quote Date', ascending=False)
    
    conn = create_connection(db_file)
    if conn is not None:
        cursor = conn.cursor()
        
        for index, row in df_sorted.iterrows():
            quote_date = row['Quote Date'].strftime('%Y-%m-%d')  # Format to "yyyy-mm-dd"
            year = int(row['Year'])
            query = f"SELECT COUNT(*) FROM {table} WHERE `Quote Date` = ? AND `Year` = ? ORDER BY `Quote Date` DESC"
            cursor.execute(query, (quote_date, year))
            exists = cursor.fetchone()[0]

            if exists == 0:
                # Convert row to DataFrame and ensure correct data types
                row_df = pd.DataFrame(row).transpose()
                row_df['Quote Date'] = pd.to_datetime(row_df['Quote Date']).dt.date
                row_df['Year'] = row_df['Year'].astype(int)
                
                row_df.to_sql(table, conn, if_exists='append', index=False)
                print(f"Appended data for {quote_date}, Year {year} to the database.")
            else:
                print(f"Skipped data for {quote_date}, Year {year} (already exists).")
        
        conn.close()
        print("Connection closed")
    else:
        print("Failed to connect to the database.")

append_csv_to_database(csv_file_path, db_file_path, table_name)
# Out:
# Connection established
# Skipped data for 2024-02-05, Year 2027 (already exists).
# Skipped data for 2024-02-05, Year 2026 (already exists).
# Skipped data for 2024-02-05, Year 2025 (already exists).
# Skipped data for 2024-02-05, Year 2024 (already exists).
# Appended data for 2024-02-02, Year 2027 to the database.
# Appended data for 2024-02-02, Year 2026 to the database.
# Appended data for 2024-02-02, Year 2025 to the database.
# Appended data for 2024-02-02, Year 2024 to the database.
# Appended data for 2024-02-01, Year 2026 to the database.
# Appended data for 2024-02-01, Year 2024 to the database.
# Appended data for 2024-02-01, Year 2025 to the database.
# Appended data for 2024-02-01, Year 2027 to the database.
# Appended data for 2024-01-31, Year 2027 to the database.
# Appended data for 2024-01-31, Year 2026 to the database.
# Appended data for 2024-01-31, Year 2025 to the database.
# Appended data for 2024-01-31, Year 2024 to the database.
# Appended data for 2024-01-30, Year 2027 to the database.
# Appended data for 2024-01-30, Year 2026 to the database.
# Appended data for 2024-01-30, Year 2025 to the database.
# Appended data for 2024-01-30, Year 2024 to the database.
# Appended data for 2024-01-29, Year 2026 to the database.
# Appended data for 2024-01-29, Year 2024 to the database.
# Appended data for 2024-01-29, Year 2025 to the database.
# Appended data for 2024-01-29, Year 2027 to the database.
# Appended data for 2024-01-25, Year 2027 to the database.
# Appended data for 2024-01-25, Year 2026 to the database.
# Appended data for 2024-01-25, Year 2025 to the database.
# Appended data for 2024-01-25, Year 2024 to the database.
# Appended data for 2024-01-24, Year 2027 to the database.
# Appended data for 2024-01-24, Year 2026 to the database.
# Appended data for 2024-01-24, Year 2025 to the database.
# Appended data for 2024-01-24, Year 2024 to the database.
# Appended data for 2024-01-23, Year 2026 to the database.
# Appended data for 2024-01-23, Year 2025 to the database.
# Appended data for 2024-01-23, Year 2024 to the database.
# Appended data for 2024-01-23, Year 2027 to the database.
# Appended data for 2024-01-22, Year 2027 to the database.
# Appended data for 2024-01-22, Year 2026 to the database.
# Appended data for 2024-01-22, Year 2025 to the database.
# Appended data for 2024-01-22, Year 2024 to the database.
# Appended data for 2024-01-19, Year 2024 to the database.
# Appended data for 2024-01-19, Year 2027 to the database.
# Appended data for 2024-01-19, Year 2026 to the database.
# Appended data for 2024-01-19, Year 2025 to the database.
# Appended data for 2024-01-18, Year 2025 to the database.
# Appended data for 2024-01-18, Year 2024 to the database.
# Appended data for 2024-01-18, Year 2027 to the database.
# Appended data for 2024-01-18, Year 2026 to the database.
# Appended data for 2024-01-17, Year 2027 to the database.
# Appended data for 2024-01-17, Year 2026 to the database.
# Appended data for 2024-01-17, Year 2025 to the database.
# Appended data for 2024-01-17, Year 2024 to the database.
# Appended data for 2024-01-16, Year 2026 to the database.
# Appended data for 2024-01-16, Year 2025 to the database.
# Appended data for 2024-01-16, Year 2024 to the database.
# Appended data for 2024-01-16, Year 2027 to the database.
# Appended data for 2024-01-15, Year 2027 to the database.
# Appended data for 2024-01-15, Year 2026 to the database.
# Appended data for 2024-01-15, Year 2025 to the database.
# Appended data for 2024-01-15, Year 2024 to the database.
# Appended data for 2024-01-12, Year 2027 to the database.
# Appended data for 2024-01-12, Year 2026 to the database.
# Appended data for 2024-01-12, Year 2025 to the database.
# Appended data for 2024-01-12, Year 2024 to the database.
# Appended data for 2024-01-11, Year 2026 to the database.
# Appended data for 2024-01-11, Year 2025 to the database.
# Appended data for 2024-01-11, Year 2024 to the database.
# Appended data for 2024-01-11, Year 2027 to the database.
# Appended data for 2024-01-10, Year 2027 to the database.
# Appended data for 2024-01-10, Year 2026 to the database.
# Appended data for 2024-01-10, Year 2025 to the database.
# Appended data for 2024-01-10, Year 2024 to the database.
# Appended data for 2024-01-09, Year 2027 to the database.
# Appended data for 2024-01-09, Year 2026 to the database.
# Appended data for 2024-01-09, Year 2025 to the database.
# Appended data for 2024-01-09, Year 2024 to the database.
# Appended data for 2024-01-08, Year 2025 to the database.
# Appended data for 2024-01-08, Year 2024 to the database.
# Appended data for 2024-01-08, Year 2026 to the database.
# Appended data for 2024-01-08, Year 2027 to the database.
# Appended data for 2023-11-21, Year 2027 to the database.
# Appended data for 2023-11-21, Year 2026 to the database.
# Appended data for 2023-11-21, Year 2025 to the database.
# Appended data for 2023-11-21, Year 2024 to the database.
# Appended data for 2023-11-20, Year 2027 to the database.
# Appended data for 2023-11-20, Year 2026 to the database.
# Appended data for 2023-11-20, Year 2025 to the database.
# Appended data for 2023-11-20, Year 2024 to the database.
# Appended data for 2023-11-17, Year 2025 to the database.
# Appended data for 2023-11-17, Year 2024 to the database.
# Appended data for 2023-11-17, Year 2027 to the database.
# Appended data for 2023-11-17, Year 2026 to the database.
# Appended data for 2023-11-16, Year 2027 to the database.
# Appended data for 2023-11-16, Year 2026 to the database.
# Appended data for 2023-11-16, Year 2025 to the database.
# Appended data for 2023-11-16, Year 2024 to the database.
# Appended data for 2023-11-10, Year 2027 to the database.
# Appended data for 2023-11-10, Year 2026 to the database.
# Appended data for 2023-11-10, Year 2025 to the database.
# Appended data for 2023-11-10, Year 2024 to the database.
# Appended data for 2023-11-08, Year 2025 to the database.
# Appended data for 2023-11-08, Year 2024 to the database.
# Appended data for 2023-11-08, Year 2027 to the database.
# Appended data for 2023-11-08, Year 2026 to the database.
# Appended data for 2023-10-27, Year 2026 to the database.
# Appended data for 2023-10-27, Year 2025 to the database.
# Appended data for 2023-10-27, Year 2024 to the database.
# Appended data for 2023-10-20, Year 2026 to the database.
# Appended data for 2023-10-20, Year 2025 to the database.
# Appended data for 2023-10-20, Year 2024 to the database.
# Appended data for 2023-10-13, Year 2025 to the database.
# Appended data for 2023-10-13, Year 2024 to the database.
# Appended data for 2023-10-13, Year 2026 to the database.
# Appended data for 2023-10-06, Year 2026 to the database.
# Appended data for 2023-10-06, Year 2025 to the database.
# Appended data for 2023-10-06, Year 2024 to the database.
# Appended data for 2023-09-29, Year 2026 to the database.
# Appended data for 2023-09-29, Year 2025 to the database.
# Appended data for 2023-09-29, Year 2024 to the database.
# Appended data for 2023-09-22, Year 2026 to the database.
# Appended data for 2023-09-22, Year 2025 to the database.
# Appended data for 2023-09-22, Year 2024 to the database.
# Appended data for 2023-09-15, Year 2024 to the database.
# Appended data for 2023-09-15, Year 2025 to the database.
# Appended data for 2023-09-15, Year 2026 to the database.
# Appended data for 2023-09-08, Year 2026 to the database.
# Appended data for 2023-09-08, Year 2025 to the database.
# Appended data for 2023-09-08, Year 2024 to the database.
# Appended data for 2023-09-01, Year 2026 to the database.
# Appended data for 2023-09-01, Year 2025 to the database.
# Appended data for 2023-09-01, Year 2024 to the database.
# Appended data for 2023-08-25, Year 2026 to the database.
# Appended data for 2023-08-25, Year 2025 to the database.
# Appended data for 2023-08-25, Year 2024 to the database.
# Appended data for 2023-08-11, Year 2025 to the database.
# Appended data for 2023-08-11, Year 2024 to the database.
# Appended data for 2023-08-11, Year 2026 to the database.
# Appended data for 2023-07-28, Year 2025 to the database.
# Appended data for 2023-07-28, Year 2024 to the database.
# Appended data for 2023-07-28, Year 2026 to the database.
# Appended data for 2023-07-14, Year 2026 to the database.
# Appended data for 2023-07-14, Year 2025 to the database.
# Appended data for 2023-07-14, Year 2024 to the database.
# Appended data for 2023-07-01, Year 2024 to the database.
# Appended data for 2023-07-01, Year 2026 to the database.
# Appended data for 2023-07-01, Year 2025 to the database.
# Appended data for 2023-06-23, Year 2026 to the database.
# Appended data for 2023-06-23, Year 2025 to the database.
# Appended data for 2023-06-23, Year 2024 to the database.
# Appended data for 2023-06-16, Year 2026 to the database.
# Appended data for 2023-06-16, Year 2025 to the database.
# Appended data for 2023-06-16, Year 2024 to the database.
# Appended data for 2023-06-09, Year 2025 to the database.
# Appended data for 2023-06-09, Year 2024 to the database.
# Appended data for 2023-06-09, Year 2026 to the database.
# Appended data for 2023-05-14, Year 2024 to the database.
# Appended data for 2023-05-14, Year 2025 to the database.
# Appended data for 2023-05-14, Year 2026 to the database.
# Appended data for 2023-04-14, Year 2026 to the database.
# Appended data for 2023-04-14, Year 2025 to the database.
# Appended data for 2023-04-14, Year 2024 to the database.
# Appended data for 2023-03-14, Year 2026 to the database.
# Appended data for 2023-03-14, Year 2025 to the database.
# Appended data for 2023-03-14, Year 2024 to the database.
# Appended data for 2023-02-14, Year 2024 to the database.
# Appended data for 2023-02-14, Year 2025 to the database.
# Appended data for 2023-02-14, Year 2026 to the database.
# Appended data for 2023-01-14, Year 2026 to the database.
# Appended data for 2023-01-14, Year 2025 to the database.
# Appended data for 2023-01-14, Year 2024 to the database.
# Appended data for 2022-12-16, Year 2025 to the database.
# Appended data for 2022-12-16, Year 2024 to the database.
# Appended data for 2022-12-16, Year 2023 to the database.
# Appended data for 2022-12-09, Year 2024 to the database.
# Appended data for 2022-12-09, Year 2023 to the database.
# Appended data for 2022-12-09, Year 2025 to the database.
# Appended data for 2022-12-02, Year 2025 to the database.
# Appended data for 2022-12-02, Year 2023 to the database.
# Appended data for 2022-12-02, Year 2024 to the database.
# Appended data for 2022-11-25, Year 2025 to the database.
# Appended data for 2022-11-25, Year 2024 to the database.
# Appended data for 2022-11-25, Year 2023 to the database.
# Appended data for 2022-11-18, Year 2025 to the database.
# Appended data for 2022-11-18, Year 2024 to the database.
# Appended data for 2022-11-18, Year 2023 to the database.
# Appended data for 2022-11-11, Year 2025 to the database.
# Appended data for 2022-11-11, Year 2024 to the database.
# Appended data for 2022-11-11, Year 2023 to the database.
# Appended data for 2022-11-04, Year 2024 to the database.
# Appended data for 2022-11-04, Year 2023 to the database.
# Appended data for 2022-11-04, Year 2025 to the database.
# Appended data for 2022-10-28, Year 2025 to the database.
# Appended data for 2022-10-28, Year 2024 to the database.
# Appended data for 2022-10-28, Year 2023 to the database.
# Appended data for 2022-10-21, Year 2025 to the database.
# Appended data for 2022-10-21, Year 2024 to the database.
# Appended data for 2022-10-21, Year 2023 to the database.
# Appended data for 2022-10-14, Year 2025 to the database.
# Appended data for 2022-10-14, Year 2024 to the database.
# Appended data for 2022-10-14, Year 2023 to the database.
# Appended data for 2022-10-07, Year 2024 to the database.
# Appended data for 2022-10-07, Year 2023 to the database.
# Appended data for 2022-10-07, Year 2025 to the database.
# Appended data for 2022-09-30, Year 2024 to the database.
# Appended data for 2022-09-30, Year 2023 to the database.
# Appended data for 2022-09-30, Year 2025 to the database.
# Appended data for 2022-09-23, Year 2025 to the database.
# Appended data for 2022-09-23, Year 2024 to the database.
# Appended data for 2022-09-23, Year 2023 to the database.
# Appended data for 2022-09-16, Year 2023 to the database.
# Appended data for 2022-09-16, Year 2025 to the database.
# Appended data for 2022-09-16, Year 2024 to the database.
# Appended data for 2022-09-09, Year 2025 to the database.
# Appended data for 2022-09-09, Year 2024 to the database.
# Appended data for 2022-09-09, Year 2023 to the database.
# Appended data for 2022-09-02, Year 2025 to the database.
# Appended data for 2022-09-02, Year 2024 to the database.
# Appended data for 2022-09-02, Year 2023 to the database.
# Appended data for 2022-08-26, Year 2025 to the database.
# Appended data for 2022-08-26, Year 2023 to the database.
# Appended data for 2022-08-26, Year 2024 to the database.
# Appended data for 2022-08-19, Year 2024 to the database.
# Appended data for 2022-08-19, Year 2023 to the database.
# Appended data for 2022-08-19, Year 2025 to the database.
# Appended data for 2022-08-12, Year 2024 to the database.
# Appended data for 2022-08-12, Year 2023 to the database.
# Appended data for 2022-08-12, Year 2025 to the database.
# Appended data for 2022-08-05, Year 2025 to the database.
# Appended data for 2022-08-05, Year 2024 to the database.
# Appended data for 2022-08-05, Year 2023 to the database.
# Appended data for 2022-07-29, Year 2023 to the database.
# Appended data for 2022-07-29, Year 2025 to the database.
# Appended data for 2022-07-29, Year 2024 to the database.
# Appended data for 2022-07-22, Year 2025 to the database.
# Appended data for 2022-07-22, Year 2024 to the database.
# Appended data for 2022-07-22, Year 2023 to the database.
# Appended data for 2022-07-15, Year 2025 to the database.
# Appended data for 2022-07-15, Year 2024 to the database.
# Appended data for 2022-07-15, Year 2023 to the database.
# Appended data for 2022-07-08, Year 2024 to the database.
# Appended data for 2022-07-08, Year 2023 to the database.
# Appended data for 2022-07-08, Year 2025 to the database.
# Appended data for 2022-07-01, Year 2023 to the database.
# Appended data for 2022-07-01, Year 2024 to the database.
# Appended data for 2022-07-01, Year 2025 to the database.
# Appended data for 2022-06-28, Year 2025 to the database.
# Appended data for 2022-06-28, Year 2024 to the database.
# Appended data for 2022-06-28, Year 2023 to the database.
# Appended data for 2022-06-24, Year 2025 to the database.
# Appended data for 2022-06-24, Year 2024 to the database.
# Appended data for 2022-06-24, Year 2023 to the database.
# Appended data for 2022-06-10, Year 2024 to the database.
# Appended data for 2022-06-10, Year 2023 to the database.
# Appended data for 2022-06-10, Year 2025 to the database.
# Appended data for 2022-06-03, Year 2025 to the database.
# Appended data for 2022-06-03, Year 2024 to the database.
# Appended data for 2022-06-03, Year 2023 to the database.
# Appended data for 2022-05-27, Year 2025 to the database.
# Appended data for 2022-05-27, Year 2024 to the database.
# Appended data for 2022-05-27, Year 2023 to the database.
# Appended data for 2022-05-20, Year 2024 to the database.
# Appended data for 2022-05-20, Year 2023 to the database.
# Appended data for 2022-05-20, Year 2025 to the database.
# Appended data for 2022-05-13, Year 2024 to the database.
# Appended data for 2022-05-13, Year 2023 to the database.
# Appended data for 2022-05-13, Year 2025 to the database.
# Appended data for 2022-05-03, Year 2023 to the database.
# Appended data for 2022-05-03, Year 2024 to the database.
# Appended data for 2022-05-03, Year 2025 to the database.
# Appended data for 2022-04-14, Year 2025 to the database.
# Appended data for 2022-04-14, Year 2024 to the database.
# Appended data for 2022-04-14, Year 2023 to the database.
# Appended data for 2022-03-28, Year 2024 to the database.
# Appended data for 2022-03-28, Year 2023 to the database.
# Appended data for 2022-03-28, Year 2022 to the database.
# Appended data for 2022-03-18, Year 2023 to the database.
# Appended data for 2022-03-18, Year 2022 to the database.
# Appended data for 2022-03-18, Year 2024 to the database.
# Appended data for 2022-03-11, Year 2024 to the database.
# Appended data for 2022-03-11, Year 2023 to the database.
# Appended data for 2022-03-11, Year 2022 to the database.
# Appended data for 2022-03-07, Year 2024 to the database.
# Appended data for 2022-03-07, Year 2023 to the database.
# Appended data for 2022-03-07, Year 2022 to the database.
# Appended data for 2022-02-25, Year 2024 to the database.
# Appended data for 2022-02-25, Year 2023 to the database.
# Appended data for 2022-02-25, Year 2022 to the database.
# Appended data for 2022-02-21, Year 2023 to the database.
# Appended data for 2022-02-21, Year 2022 to the database.
# Appended data for 2022-02-21, Year 2024 to the database.
# Appended data for 2022-02-11, Year 2024 to the database.
# Appended data for 2022-02-11, Year 2023 to the database.
# Appended data for 2022-02-11, Year 2022 to the database.
# Appended data for 2022-02-04, Year 2024 to the database.
# Appended data for 2022-02-04, Year 2023 to the database.
# Appended data for 2022-02-04, Year 2022 to the database.
# Appended data for 2022-01-28, Year 2024 to the database.
# Appended data for 2022-01-28, Year 2023 to the database.
# Appended data for 2022-01-28, Year 2022 to the database.
# Appended data for 2022-01-21, Year 2022 to the database.
# Appended data for 2022-01-21, Year 2023 to the database.
# Appended data for 2022-01-21, Year 2024 to the database.
# Appended data for 2022-01-20, Year 2024 to the database.
# Appended data for 2022-01-20, Year 2023 to the database.
# Appended data for 2022-01-20, Year 2022 to the database.
# Appended data for 2022-01-14, Year 2024 to the database.
# Appended data for 2022-01-14, Year 2023 to the database.
# Appended data for 2022-01-14, Year 2022 to the database.
# Appended data for 2022-01-12, Year 2024 to the database.
# Appended data for 2022-01-12, Year 2023 to the database.
# Appended data for 2022-01-12, Year 2022 to the database.
# Appended data for 2021-12-17, Year 2023 to the database.
# Appended data for 2021-12-17, Year 2022 to the database.
# Appended data for 2021-12-17, Year 2024 to the database.
# Appended data for 2021-12-10, Year 2023 to the database.
# Appended data for 2021-12-10, Year 2022 to the database.
# Appended data for 2021-12-10, Year 2024 to the database.
# Appended data for 2021-12-03, Year 2024 to the database.
# Appended data for 2021-12-03, Year 2023 to the database.
# Appended data for 2021-12-03, Year 2022 to the database.
# Appended data for 2021-11-26, Year 2022 to the database.
# Appended data for 2021-11-26, Year 2024 to the database.
# Appended data for 2021-11-26, Year 2023 to the database.
# Appended data for 2021-11-19, Year 2024 to the database.
# Appended data for 2021-11-19, Year 2023 to the database.
# Appended data for 2021-11-19, Year 2022 to the database.
# Appended data for 2021-11-12, Year 2024 to the database.
# Appended data for 2021-11-12, Year 2023 to the database.
# Appended data for 2021-11-12, Year 2022 to the database.
# Appended data for 2021-11-05, Year 2023 to the database.
# Appended data for 2021-11-05, Year 2022 to the database.
# Appended data for 2021-11-05, Year 2024 to the database.
# Appended data for 2021-10-29, Year 2022 to the database.
# Appended data for 2021-10-29, Year 2023 to the database.
# Appended data for 2021-10-29, Year 2024 to the database.
# Appended data for 2021-10-22, Year 2024 to the database.
# Appended data for 2021-10-22, Year 2023 to the database.
# Appended data for 2021-10-22, Year 2022 to the database.
# Appended data for 2021-10-19, Year 2024 to the database.
# Appended data for 2021-10-19, Year 2023 to the database.
# Appended data for 2021-10-19, Year 2022 to the database.
# Appended data for 2021-10-15, Year 2023 to the database.
# Appended data for 2021-10-15, Year 2022 to the database.
# Appended data for 2021-10-15, Year 2024 to the database.
# Appended data for 2021-10-08, Year 2024 to the database.
# Appended data for 2021-10-08, Year 2023 to the database.
# Appended data for 2021-10-08, Year 2022 to the database.
# Appended data for 2021-09-27, Year 2024 to the database.
# Appended data for 2021-09-27, Year 2023 to the database.
# Appended data for 2021-09-27, Year 2022 to the database.
# Appended data for 2021-09-23, Year 2023 to the database.
# Appended data for 2021-09-23, Year 2022 to the database.
# Appended data for 2021-09-23, Year 2024 to the database.
# Appended data for 2021-09-20, Year 2023 to the database.
# Appended data for 2021-09-20, Year 2022 to the database.
# Appended data for 2021-09-20, Year 2024 to the database.
# Appended data for 2021-09-10, Year 2024 to the database.
# Appended data for 2021-09-10, Year 2023 to the database.
# Appended data for 2021-09-10, Year 2022 to the database.
# Connection closed
